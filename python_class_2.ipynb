# %% [markdown]
# <a href="https://colab.research.google.com/github/Soybeania/learning-python-no.2/blob/main/python_class_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #使用pillow做影像處理

# %% [markdown]
# ##read an image

# %%
from PIL import Image

# %%
img = Image.open('OBAMAAAA.png')

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=586x664>

# %%
img.size
(183, 274)
# Out:
# (183, 274)

# %%
img.mode
# Out:
# 'RGBA'

# %%
img.format
# Out:
# 'PNG'

# %%
##Convert color pictures to one color

# %% [markdown]
# ##圖形存在

# %%
img.convert('L').save("obama.webp")

# %% [markdown]
# ###圖形縮小
#
# * resize
# * thumbnail

# %%
img.resize?

# %%
img.resize((103,200))
# Out:
# <PIL.Image.Image image mode=RGBA size=103x200>

# %%
img01 = img.copy()

# %%
img01. thumbnail?
# Out:
# Object `thumbnail` not found.

# %%
img01
# Out:
# <PIL.Image.Image image mode=RGBA size=586x664>

# %% [markdown]
# ### 圖形rotate
#
# - transpose
# - rotate

# %%
img01
# Out:
# <PIL.Image.Image image mode=RGBA size=586x664>

# %%
img01. transpose?

# %%
img01.transpose(Image.Transpose.ROTATE_90)
# Out:
# <PIL.Image.Image image mode=RGBA size=664x586>

# %%
from PIL import Image

# %%
img = Image.open('Feyd rautha.png')

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=664x600>

# %%
img.size
# Out:
# (664, 600)

# %%
img.resize((28,50))
# Out:
# <PIL.Image.Image image mode=RGBA size=28x50>

# %%
img.save("Stupid person.png")

# %%
img.rotate?

# %%
img.rotate(45,expand= 1, fillcolor = "white")
# Out:
# <PIL.Image.Image image mode=RGBA size=894x894>

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=664x600>

# %%
img.mode
# Out:
# 'RGBA'

# %%
r, g, b, a = img.split()
Image.merge('RGB', (b,g,r))
# Out:
# <PIL.Image.Image image mode=RGB size=664x600>

# %%
img.size
# Out:
# (664, 600)

# %%
img.crop((190, 15, 540, 550))
#left, up, right, down
# Out:
# <PIL.Image.Image image mode=RGBA size=350x535>
